# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date    Lat     Lng  \
# 0        0          Beyneu      KZ  2020-08-19 02:04:30  45.32   55.20
# 1        1      Hambantota      LK  2020-08-19 02:04:30   6.12   81.12
# 2        2         Isangel      VU  2020-08-19 02:04:01 -19.55  169.27
# 3        3           Alofi      NU  2020-08-19 02:01:06 -19.06 -169.92
# 4        4  Cabo San Lucas      MX  2020-08-19 02:01:03  22.89 -109.91
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     66.65        70           0        5.91
# 1     77.00       100         100        8.05
# 2     78.80        65          20        8.05
# 3     76.86        84          83       22.77
# 4     86.00        62          90        5.82

# %%
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
gmaps.configure(api_key=g_key)

# %%
locations = city_data_df[["Lat", "Lng"]]
#assign the weights variable (this p much means how light or heavy the color is based on impact/value)
max_temp = city_data_df["Max Temp"]
#assign figure variable to the gmaps.figure() attribute
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# assign heatmap_layer variable to the heatmap_layer attribute and add in the locations
heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)

#add the heatmap layer
fig.add_layer(heat_layer)

#call the figure to plot data
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of wind speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date    Lat     Lng  \
# 1         1      Hambantota      LK  2020-08-19 02:04:30   6.12   81.12
# 2         2         Isangel      VU  2020-08-19 02:04:01 -19.55  169.27
# 3         3           Alofi      NU  2020-08-19 02:01:06 -19.06 -169.92
# 4         4  Cabo San Lucas      MX  2020-08-19 02:01:03  22.89 -109.91
# 5         5          Avarua      CK  2020-08-19 02:02:09 -21.21 -159.78
# 6         6          Monjas      GT  2020-08-19 02:04:30  14.50  -89.87
# 19       19       Kavaratti      IN  2020-08-19 02:04:31  10.57   72.64
# 27       27          Nabire      ID  2020-08-19 02:04:32  -3.37  135.48
# 28       28      Butaritari      KI  2020-08-19 02:03:57   3.07  172.79
# 29       29    Port Hedland      AU  2020-08-19 02:04:32 -20.32  118.57
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 1      77.00       100         100        8.05
# 2      78.80        65          20        8.05
# ...

# %%
preferred_cities_df.isnull().sum()
# Out:
# City_ID       0
# City          0
# Country       0
# Date          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# dtype: int64

# %%
# Create DataFrame to store hotel names w/ city, country, max temp, and coordinates
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp    Lat     Lng Hotel Name
# 1       Hambantota      LK     77.00   6.12   81.12
# 2          Isangel      VU     78.80 -19.55  169.27
# 3            Alofi      NU     76.86 -19.06 -169.92
# 4   Cabo San Lucas      MX     86.00  22.89 -109.91
# 5           Avarua      CK     75.20 -21.21 -159.78
# 6           Monjas      GT     82.40  14.50  -89.87
# 19       Kavaratti      IN     81.39  10.57   72.64
# 27          Nabire      ID     82.60  -3.37  135.48
# 28      Butaritari      KI     83.79   3.07  172.79
# 29    Port Hedland      AU     77.00 -20.32  118.57

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()
hotels
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHAEAADgU-PaKxNU1RegknuR-xt6gG3ZNpucKDijAj5TtNPidI27FT69P9rsCm7GWGMMWSuJa1dfIrnwnKzVJZ9UBYa6ZphsxGCV0rATALIiNiKL40R2rvL5mGzO6OQoEPg1xK2MS-kc8xtnHScmCmO7Q93r1GFE7nLa7OWpXHGm4csf6RWwjGdrWHeN0O8JpKXnRno6Wf31gPmolmHvEt0l9yW3Ln3D7w0Nts2sbMh3vVsMwIbrLN659fcw2SEWfQSBjmCbzXwL9mHhHCh6Lu5EOLzJjP04odChNbKcrW4U3346S2IwWcgnNizHFM4oSI_ersMS6y1NNl7j_rEHn7ks3uyFjQJtX3LV-DWP0IDcuf0-UYwEJOkJq9duD9r8oXq3a7hIQflfxDZmjTqLiTp-17pEy0hoUbslOfpiCJb-I9AeD_KCpdh3K3bA',
#  'results': [{'business_status': 'OPERATIONAL',
#    'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277},
#     'viewport': {'northeast': {'lat': 48.8594393802915,
#       'lng': 2.354352980291502},
#      'southwest': {'lat': 48.8567414197085, 'lng': 2.351655019708498}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png',
#    'name': 'Hôtel Duo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
# ...

# %%
len(hotels["results"])
# Out:
# 20

# %%
hotels["results"][0]["name"]
# df, column, index, key is how I got the value below
# Out:
# 'Hôtel Duo'

# %%
# interate thru dataframe
for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    
    #add lat and lng to the location key in the params dictionary (this makes them values of that key)
    params["location"] = f"{lat},{lng}"
    #create needed url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    #request json data 
    hotels = requests.get(base_url, params=params).json()
    #check first hotel and store
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except(IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#               City Country  Max Temp    Lat     Lng  \
# 1       Hambantota      LK     77.00   6.12   81.12
# 2          Isangel      VU     78.80 -19.55  169.27
# 3            Alofi      NU     76.86 -19.06 -169.92
# 4   Cabo San Lucas      MX     86.00  22.89 -109.91
# 5           Avarua      CK     75.20 -21.21 -159.78
# 6           Monjas      GT     82.40  14.50  -89.87
# 19       Kavaratti      IN     81.39  10.57   72.64
# 27          Nabire      ID     82.60  -3.37  135.48
# 28      Butaritari      KI     83.79   3.07  172.79
# 29    Port Hedland      AU     77.00 -20.32  118.57
#
#                      Hotel Name
# 1                   Bungalow 63
# 2   Volcano Sea View Tree House
# 3                 Taloa Heights
# 4        Hotel Tesoro Los Cabos
# 5                  Paradise Inn
# 6              Hotel El Viajero
# 19  Bismillah Hotel And Lodging
# 27       Hotel Nusantara Nabire
# 28           Isles Sunset Lodge
# 29          The Esplanade Hotel

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""
# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
